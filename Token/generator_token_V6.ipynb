# %% [markdown]
# # Required Imports

# %%
import sys, random, math, pickle
from time import time
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.nn.functional as F
from torch.nn import MSELoss
import seaborn as sns
from tensorboard import default
import torch.nn.functional as F
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
sys.path.append('DG/gan')
import gc
print(device)
from torch.nn import TransformerEncoder, TransformerEncoderLayer
# Out:
# cuda:0

# %%
from pynvml import *
nvmlInit()
h = nvmlDeviceGetHandleByIndex(1)
info = nvmlDeviceGetMemoryInfo(h)
print(f'total    : {info.total}')
print(f'free     : {info.free}')
print(f'used     : {info.used}')
# Out:
# total    : 50962169856
# free     : 21112487936
# used     : 29849681920

# %% [markdown]
# # Import Real Training Data to Generate New Data from it.
#
# ### Actual Distribution
# - Class0: 6250
# - Class1: 16124
# - Class2: 21273
# - Class3: 5278

# %%
def get_one_class(X,Y,flag,class_label): # (X, Y, and flag) are the whole dataset that is consisted of many classes, Y is NOT One-Hot Encoded
    indices_class_label = np.where(Y==class_label)
    X,Y,flag = X[indices_class_label], Y[indices_class_label], flag[indices_class_label] 
    indices_non_zero = torch.nonzero(torch.sum(flag,1)-1).squeeze()
    return X[indices_non_zero], Y[indices_non_zero], flag[indices_non_zero]

def get_n_samples(X,Y,flag,n_samples):
    randomList = random.sample(range(0, Y.shape[0]), n_samples)
    return X[randomList], Y[randomList], flag[randomList]

# In real data, if flag sum is 1 --> Then no timestep at all. --> So we do remove those ones by converting them to zeros, then remove from the list
# In real data, there is no flag of length ZERO
def remove_zero_datapoints(X,Y,flag):
    indices_non_zero = torch.nonzero(torch.sum(flag,1)-1).squeeze()
    return X[indices_non_zero], Y[indices_non_zero], flag[indices_non_zero]

# %%
training_real = np.load('../data/google/data_train_reduced.npz')

real_train_X = torch.from_numpy(training_real['data_feature']).float() #[50000, 2500, 9]
real_train_Y = torch.from_numpy(training_real['data_attribute']) #[50000,4]
real_train_Y_labels = torch.argmax(real_train_Y,1) #[50000,]  returns a list of the class label, no one hot encoding any more
real_train_flags = torch.from_numpy(training_real['data_gen_flag'])   # (50000, 2500)

#------------------------------------------------------------------Loading One Class------------------------------------------------
real_train_X, real_train_Y_labels, real_train_flags= remove_zero_datapoints(real_train_X, real_train_Y_labels, real_train_flags)

# The pading mask need to be inverted 

padding_mask = real_train_flags == 0 # True when padding, False when considering

real_train_lengths = torch.sum(real_train_flags,1).long()

# %% [markdown]
# # PyTorch Transformer Model
#
# - Later, we need to remove this from here and put in a separate folder

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x).to(device)

# %%
class TimeSeriesTransformer(nn.Module):

    def __init__(self, n_features=9, n_auxiliary=2, d_model=256, n_heads=8, n_hidden=256,n_hidden_disc=64, n_layers=8, dropout=0.0, S=400):
        super().__init__()
        self.model_type = 'Time Series Transformer Model'
        self.InputLinear = nn.Linear(n_features, d_model)
        
        self.positional_encoding = PositionalEncoding(d_model, dropout)
        encoder_layers = TransformerEncoderLayer(d_model, n_heads, n_hidden, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, n_layers)
        
        self.d_model = d_model
        self.n_features = n_features
        
        self.OutputLinear = nn.Linear(d_model, n_features) # The output of the encoder is similar to the input of the encoder, both are (B,S,d_model)
        self.aux_layer1 = nn.Linear(n_features, n_hidden_disc) 
        self.aux_layer2 = nn.Linear(n_hidden_disc, n_hidden_disc) 
        self.aux_layer3 = nn.Linear(n_hidden_disc, n_auxiliary)
        
        self.init_weights()
        self.activation = nn.Sigmoid()
        
    def generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float(-1e6)).masked_fill(mask == 1, float(0.0))
        return mask 

    def init_weights(self):
        initrange = 0.1
        self.InputLinear.weight.data.uniform_(-initrange, initrange)
        self.OutputLinear.bias.data.zero_()
        self.OutputLinear.weight.data.uniform_(-initrange, initrange)

    def forward(self, src, src_mask,padding_mask):
        src = self.InputLinear(src) * math.sqrt(self.d_model)
        src = self.positional_encoding(src)
        output = self.transformer_encoder(src, src_mask,padding_mask)
        output = self.OutputLinear(output)
        output1 = self.activation(output) # output[...,:9] --> Actual 9 values
        output2 = self.aux_layer3(self.aux_layer2(self.aux_layer1(output))) #aux
        return output1,output2

# %%
model = TimeSeriesTransformer().to(device)

# ck = torch.load('lightning_logs/version_36/checkpoints/epoch=257-step=49535.ckpt')['state_dict']
# model.load_state_dict(ck)

model.load_state_dict(torch.load('W_transformer_token_V6'))
model.eval()
print()

# %%
model.class_weights
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-b6e6ed23f9db> in <module>
# ----> 1 model.class_weights
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     946                 return modules[name]
#     947         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 948             type(self).__name__, name))
#     949
#     950     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'TimeSeriesTransformer' object has no attribute 'class_weights'

# %% [markdown]
# # Generating New Data

# %%
################################# The following is the generating part #################################

# Returns: X (The data)
# Returns: masks (e.g. [False,Flase,True,True,True,....,True]), False is the actual Data

resulted_masks = []
generated_dataset_Y=[]
generated_dataset_X=[]

def generate_dataset(X,Y,masks,n_seed,n_samples,max_length):
    for n in range(n_samples):
        
        datapoint,y,mask = get_n_samples(X,Y,masks,n_samples=1) # The first 10 timesteps of just one sample
        datapoint = datapoint[:,:n_seed].permute(1,0,2) 
        datapoint_len = torch.sum(~mask) #Flip and count, you will get the actual length to generate likewise
        mask = mask[:,:n_seed] 
        E = datapoint.size(2)
        S = datapoint.size(0)
        #print(datapoint_len)
        for t in range(max_length-n_seed): # Loop until 400 timesteps
            src_mask = model.generate_square_subsequent_mask(S)
            Y_predicted, aux_predicted = model(datapoint.to(device),src_mask.to(device),mask.to(device))
            Y_predicted = Y_predicted.cpu()
            one_new_timestep=Y_predicted[-1].unsqueeze(0)
            #print(F.softmax(aux_predicted[-1]))
            #print(aux_predicted.squeeze().shape)
            #print(F.softmax(aux_predicted[-1]).argmax().item())
            #print(F.softmax(aux_predicted[-1]).argmax().item(),aux_predicted[-1])
            if F.softmax(aux_predicted[-1]).argmax().item() == 1:
                print(datapoint_len,S)
                datapoint = torch.cat((datapoint,torch.zeros((max_length-S,1,E)))).cpu()# Pad remainings with zero
                mask =  torch.cat((mask,torch.full((1,max_length-S),True)),1)
        
                break
            
            datapoint = torch.cat((datapoint,one_new_timestep)) # add the forecasted timestep
            mask = torch.cat((mask,torch.tensor([[False]])),1 )
            S = datapoint.size(0)
            
        resulted_masks.append(mask.numpy())
        generated_dataset_X.append(datapoint.permute(1,0,2).squeeze().detach().numpy())
        generated_dataset_Y.append(y.item())
        del mask
        del datapoint
        del one_new_timestep
        gc.collect(),torch.cuda.empty_cache()
        
        if (n%100==0):
            print('{}/{}'.format(n,n_samples))
        if ((n+1)%1000==0):
             np.savez('npz_transformer_token_V6',X=generated_dataset_X,masks= resulted_masks,Y=generated_dataset_Y)

max_length = 400
n_seed = 2
# Padding Mask Fed here is the Mask where "False is Real Data", True is masked and ignore them

# %%
gc.collect()
real_train_X0 ,real_train_Y_labels0 ,padding_mask0= get_one_class(real_train_X ,real_train_Y_labels ,padding_mask,0)
real_train_X1 ,real_train_Y_labels1 ,padding_mask1= get_one_class(real_train_X ,real_train_Y_labels ,padding_mask,1)
real_train_X2 ,real_train_Y_labels2 ,padding_mask2= get_one_class(real_train_X ,real_train_Y_labels ,padding_mask,2)
real_train_X3 ,real_train_Y_labels3 ,padding_mask3= get_one_class(real_train_X ,real_train_Y_labels ,padding_mask,3)



generate_dataset(real_train_X0 ,real_train_Y_labels0 ,padding_mask0,n_seed=n_seed,n_samples=real_train_X0.size(0),max_length=max_length)
generate_dataset(real_train_X1 ,real_train_Y_labels1 ,padding_mask1,n_seed=n_seed,n_samples=real_train_X1.size(0),max_length=max_length)
generate_dataset(real_train_X2 ,real_train_Y_labels2 ,padding_mask2,n_seed=n_seed,n_samples=real_train_X2.size(0),max_length=max_length)
generate_dataset(real_train_X3 ,real_train_Y_labels3 ,padding_mask3,n_seed=n_seed,n_samples=real_train_X3.size(0),max_length=max_length)
# Out:
# /rhome/yelnady/.local/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /rhome/yelnady/.local/lib/python3.6/site-packages/ipykernel_launcher.py:29: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 0 tensor([[ 1.3202, -0.9164]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 1.8203, -1.5122]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.0274, -5.6356]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3676, -6.4029]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.1558, -5.9694]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7826, -7.0954]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.6659, -6.8386]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3143, -6.2235]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.5693, -6.7181]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7993, -7.0392]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8507, -7.1453]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4696, -6.3724]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 3.0031, -3.6346]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 3.1405, -3.8432]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4498, -6.4026]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8730, -7.2865]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9493, -7.4994]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9134, -7.4616]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4668, -6.4914]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4707, -6.4562]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7448, -7.0529]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8733, -7.3035]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8025, -7.2357]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8678, -7.3955]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8953, -7.4777]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8422, -7.3490]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.6599, -6.9384]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.2656, -6.1894]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9147, -7.3397]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8382, -7.2119]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7226, -7.0390]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7530, -7.1433]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8736, -7.4008]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8229, -7.3426]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 3.5323, -5.0083]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7162, -7.1847]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8572, -7.4743]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9695, -7.6683]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0030, -7.7357]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0278, -7.7866]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0351, -7.7874]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9713, -7.6575]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0031, -7.6821]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0571, -7.7239]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0612, -7.7079]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0791, -7.7578]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0627, -7.7550]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9909, -7.6373]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7370, -7.1919]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3381, -6.5057]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.5102, -6.8290]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.5983, -7.0613]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 3.6968, -5.4980]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 3.6512, -5.3693]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.2623, -6.4476]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7349, -7.2708]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8493, -7.4661]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8439, -7.4375]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9157, -7.5518]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9129, -7.5612]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7479, -7.2458]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8552, -7.4516]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9229, -7.5536]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9656, -7.5875]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8801, -7.4226]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8016, -7.3186]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7562, -7.2927]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7854, -7.4153]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8738, -7.6108]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9709, -7.7931]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0310, -7.8994]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9675, -7.7892]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8628, -7.6160]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8198, -7.5957]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.6566, -7.3328]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.5991, -7.2249]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7584, -7.4848]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8634, -7.5798]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8334, -7.4115]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.6701, -7.0408]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4391, -6.5738]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.6583, -6.9471]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8265, -7.3303]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9281, -7.6125]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9619, -7.7316]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9695, -7.7508]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9963, -7.7714]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0442, -7.8201]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0811, -7.8546]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.
], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.1502, -9.2039]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.1269, -9.1631]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 5.0612, -9.0747]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9624, -8.9496]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8952, -8.8700]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9084, -8.8996]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9508, -8.9562]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9780, -8.9771]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9651, -8.9401]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.9293, -8.8792]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8725, -8.7970]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8216, -8.7270]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8059, -8.7081]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.8049, -8.7017]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7818, -8.6514]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.7055, -8.5119]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.5804, -8.2936]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4519, -8.0803]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3647, -7.9454]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3753, -7.9700]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4853, -8.1457]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.5952, -8.3129]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.6567, -8.3981]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.6449, -8.3683]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.5680, -8.2426]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4703, -8.0881]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3865, -7.9520]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3181, -7.8379]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.2790, -7.7712]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.2343, -7.6944]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.1695, -7.5820]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.1433, -7.5339]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.1440, -7.5283]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.1130, -7.4681]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.0724, -7.3961]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.1034, -7.4542]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.2418, -7.6953]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3665, -7.8999]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4490, -8.0228]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4363, -7.9849]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3644, -7.8550]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.2650, -7.6918]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.2654, -7.7067]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3656, -7.8830]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4550, -8.0238]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.4725, -8.0318]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 4.3475, -7.7997]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 3.9537, -7.1076]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 3.0540, -5.5162]], device='cuda:0', grad_fn=<SelectBackward>)
# 0 tensor([[ 1.2679, -2.2207]], device='cuda:0', grad_fn=<SelectBackward>)
# 1 tensor([[-0.9662,  3.1228]], device='cuda:0', grad_fn=<SelectBackward>)
# tensor(8) 78
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-52c0cb39abd6> in <module>
#       6
#       7
# ----> 8 generate_dataset(real_train_X0 ,real_train_Y_labels0 ,padding_mask0,n_seed=n_seed,n_samples=real_train_X0.size(0),max_length=max_length)
#       9 generate_dataset(real_train_X1 ,real_train_Y_labels1 ,padding_mask1,n_seed=n_seed,n_samples=real_train_X1.size(0),max_length=max_length)
#      10 generate_dataset(real_train_X2 ,real_train_Y_labels2 ,padding_mask2,n_seed=n_seed,n_samples=real_train_X2.size(0),max_length=max_length)
#
# <ipython-input-17-e655a22bc865> in generate_dataset(X, Y, masks, n_seed, n_samples, max_length)
#      44         del datapoint
#      45         del one_new_timestep
# ---> 46         gc.collect(),torch.cuda.empty_cache()
#      47
#      48         if (n%100==0):
#
# ~/.local/lib/python3.6/site-packages/torch/cuda/memory.py in empty_cache()
#     112     """
#     113     if is_initialized():
# --> 114         torch._C._cuda_emptyCache()
#     115
#     116
#
# KeyboardInterrupt:

# %%
np.savez('npz_transformer_token_V6',X=generated_dataset_X,masks= resulted_masks,Y=generated_dataset_Y)

# %%
gc.collect(),torch.cuda.empty_cache()

# %%
# What is the average values of all samples in variable length sequence

mean_of_samples = []
for x,length in zip(real_train_X, real_train_lengths):
    mean_of_samples.append(torch.sum(x)/(9*length)) # torch.Size([2500])
    
print(np.mean(mean_of_samples))

# %%
# torch.max(input) → Tensor
# Returns the maximum value of all elements in the input tensor.

torch.max(real_train_X.flatten())

# %%
torch.min(real_train_X.flatten())

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.plot(real_train_X.flatten(), 'o', color='black');
plt.xscale("log")
ax.set_title('CDF - Class all')
ax.set_xlabel('The Sequence Length')

# %%
torch.mean(real_train_X,2).shape

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.hist(torch.mean(real_train_X,2).flatten(), 'o', color='black');
plt.xscale("log")
ax.set_title('CDF - Class all')
ax.set_xlabel('The Sequence Length')

# %%
plt.hist([1,1,1,2])
